# %%
#List that includes all names of territories
import random 

player_1_random_list = random.sample(territory_list,9)
player_2_random_list = territory_list.remove(player_1_random_list)
computer_random_list = territory_list.remove(player_1_random_list)

player_1[territory]:player_1_random_list
player_2[territory]:player_2_random_list
computer[territory]:computer_random_list

for i in player_1_random_list:
    while count != 20:
        print(f'Player 1, how many infantry do you want to assign to {i} ?')
        player_1[territory[i]]:int(input())
        count+=1
        print(f'you have {player_1[infantry] - count} infantry left')
        if count == player_1[infantry]:
            print('No more infantry left')
            
for i in player_2_random_list:
    print(f'Player 2, how many infantry do you want to assign to {i} ?')
    player_1[territory[i]]:int(input())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4ab56732dfae> in <module>
#       2 import random
#       3
# ----> 4 player_1_random_list = random.sample(territory_list,9)
#       5 player_2_random_list = territory_list.remove(player_1_random_list)
#       6 computer_random_list = territory_list.remove(player_1_random_list)
#
# NameError: name 'territory_list' is not defined

# %%
#List that includes all names of territories
import random 

def random_dist(dict_glob, player_dict_1, player_list_2)
player_dict_1['Territory'] : random.sample(dict_global['territory_list'],9)
player_dict_2['Territory'] : dict_global['territory_list'].remove(player_dict_1['Territory'])
computer_random['Territory'] : dict_global['territory_list'].remove(player_dict_1['Territory'])



def infintry_alloc(numb,player_list_1):
    for i in player_1_random_list:
        while count != 20:
            print(f'Player {numb}, how many infantry do you want to assign to {i} ?')
            player_1[territory[i]]:int(input())
            count+=1
            print(f'you have {player_1[infantry] - count} infantry left')
            if count == player_1[infantry]:
                print('No more infantry left')

# %%
#1. Lets defines the variables before everything

#Dictionnaries
dict_main = {'Asia': ['China', 'India', 'Cyberia'],
'North_America': ['Canada', 'United_Stated', 'Mexico'],
'South_America': ['Brazil', 'Peru', 'Argentina'],
'Europe': ['Western_Europe', 'Eastern_Europe', 'North_Europe'],
'Africa': ['North_Africa', 'Western_Africa', 'South_Africa'],
'Oceana': ['Australia', 'New_Zealand', 'Indonesia'],'China': ['India','Cyberia','Australia'],
'India': ['China','Cyberia','Eastern_Europe'],
'Cyberia': ['China','India','Canada'],
'Canada': ['United_Stated','Cyberia','Western_Europe'],
'United_Stated': ['Canada','Mexico'],
'Mexico': ['United_Stated','Peru'],
'Peru': ['Mexico','Brazil','Argentina'],
'Argentina': ['Peru','Brazil'],
'Brazil': ['Peru','Argentina','Western_Africa'],
'Western_Europe': ['Eastern_Europe','North_Europe','Canada','North_Africa'],
'Eastern_Europe': ['Western_Europe','North_Europe','Cyberia','India','North_Africa'],
'North_Europe': ['Western_Europe','Cyberia','Eastern_Europe'],
'North_Africa': ['Eastern_Europe','Western_Europe','India'],
'Western_Africa': ['North_Africa','South_Africa'],
'South_Africa': ['Western_Africa','North_Africa','India'],
'Australia': ['New_Zealand','Indonesia'],
'New_Zealand': ['Indonesia','Australia'],
'Indonesia': ['New_Zealand','Australia','China','India']}

list_territories = ['India','Cyberia','Australia','Canada', 'United_Stated', 'Mexico','Brazil', 'Peru', 'Argentina','Western_Europe', 'Eastern_Europe', 'North_Europe','North_Africa', 'Western_Africa', 'South_Africa','Australia', 'New_Zealand', 'Indonesia']
#Player dictionary
# infantry = number of infantry on the map or a the biggening of the game
# cards = cards and bonus got amoung the turns, start by 0
# territories = territories owed by the player at the beginning of the game and conquered along the game (start = 9, max=18)

player_1={'Infantry':20, 'Cards':0, 'Territory': [],'Full_Continent':0}
player_2={'Infantry':20, 'Cards':0, 'Territory': [],'Full_Continent':0}
#computer={'Infantry':20, 'Cards':0, 'Territory': []}

#Import random library
import random
import math
lst_1 = []
lst_2 = []
nb_of_rounds = 0
player_turn = "Wawa"

#This function will randomly split all the territories of the world to all players in order to start the game
def random_dist(dict_glob, player_dict_1, player_dict_2):

      lst_1 = random.sample(list_territories,9)
      player_1['Territory'] = lst_1

      for i in list_territories:
          if i not in lst_1 :
             player_2['Territory'].append(i)

      #print(player_1)
      #print(player_2)
      return player_1,player_2

random_dist(dict_main,player_1,player_2)

#This function will allow the user to choose between random or strategic allocation for delta infantry at the begining 
"""
def choice_delta_infantry_allocation_type(numb,player_list_1):
  
  choice = input("Tape 1 for random allocation or 2 for strategic allocation")

  if choice == "1":
"""

#This function should only run once before the first round
def infantry_alloc(player_turn,player_dict_1):

      for i in player_1['Territory']:
          #Add 1 amry by territory randomly distributed to this player 
          #print(i)
          player_1.update({i:1})

      #Add 1 amry by territory randomly distributed to this player
      armies_to_be_deployed = player_1['Infantry'] - len(player_1['Territory'])

      #while armies_to_be_deployed > 0:

      for i in player_1['Territory']:
        #print(f'Player {num} you have {x} artillary left, how many do you want to assign to {i} ?')
          #z = int(input("Assign "+i))
          z=int(input(f'Player {player_turn} you have {armies_to_be_deployed} artillary left, how many do you want to assign to => {i}?'))
          y=z+1
          player_1.update({i:y})

      return player_1,armies_to_be_deployed
      

print(infantry_alloc(player_1,player_turn))
